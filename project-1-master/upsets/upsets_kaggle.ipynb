# %%
# Dependencies
import pandas as pd
import numpy as np
from pprint import pprint

# %%
# Read CSV 
csv = "games_clean.csv"
games = pd.read_csv(csv)
games = games.drop(columns=["Unnamed: 0"])

# %%
games["Skill Disparity"] = abs(games["White Rating"] - games["Black Rating"])
# Favored
favored = []
favor = games["White Rating"] > games["Black Rating"]
for value in favor:
    if value == True:
        favored.append("white")
    else:
        favored.append("black")

games["Favored"] = favored

# Upset
upset = []
ups = (games["Favored"] != games["Winner"]) & (games["Winner"] != "draw")
for value in ups:
    if value == True:
        upset.append("True")
    else:
        upset.append("False")
games["Upset"] = upset
games

# Skill Disparity Bin
bin = (0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 3000)
label = ["0-100", "101-200", "201-300", "301-400", "401-500", "501-600", "601-700", "701-800", "801-900", "901-1000", "1000+"]

games["Disparity Group"] = pd.cut(games["Skill Disparity"], bin, labels=label)
games
# Out:
#         Game ID  Rated  Turns Victory Status Winner Increment Code  \
# 0      l1NXvwaE   True     16         resign  black           5+10
# 1      mIICvQHh   True     61           mate  white           5+10
# 2      kWKvrqYL   True     61           mate  white           20+0
# 3      9tXo1AUZ   True     95           mate  white           30+3
# 4      MsoDV9wj  False      5           draw   draw           10+0
# 5      qwU9rasv   True     33         resign  white           10+0
# 6      RVN0N3VK  False      9         resign  black          15+30
# 7      dwF3DJHO   True     66         resign  black           15+0
# 8      afoMwnLg   True    119           mate  white           10+0
# 9      HgKLWPsz  False     39           mate  white          20+60
# 10     Vf5fKWzI  False     38         resign  black          20+60
# 11     HRti5mKv  False     60         resign  black           5+40
# 12     2fEjSei6  False     31         resign  black            8+0
# 13     u7i6dOaJ  False     31           mate  white          15+15
# 14     guanvMR5  False     43         resign  black          15+15
# 15     PmpkWkmm  False     52         resign  black          15+15
# 16     EwaK0IsE  False     66           mate  black          15+16
# 17     yrSDozT3  False    101         resign  black          15+15
# 18     x31mXlvc  False     25         resign  white           11+0
# 19     oQklnWWp  False     14         resign  black          15+15
# 20     QFCZwY1f  False      3         resign  white          30+60
# 21     5cgBygpI  False     17         resign  white           15+5
# 22     UhXXBOMY   True     36         resign  white           10+0
# 23     mCij4hBq   True     13         resign  black           10+0
# 24     ifUMWtVj   True     69           mate  white          10+10
# 25     Wf0zuLQQ   True     43         resign  white          10+10
# 26     srz9QfSN   True     54           mate  black          10+10
# 27     NS6ccssb   True     53         resign  black          10+10
# 28     M3vpf2Ki   True     66           mate  black          10+10
# 29     fXhNOnOn   True     64         resign  black          10+10
# ...         ...    ...    ...            ...    ...            ...
# 18348  3ium8obe   True     47           mate  white           10+0
# 18349  8HGqt5cf   True    115           mate  white           10+0
# 18350  2PG68cOv   True     37         resign  black          15+15
# 18351  F6akm0V3   True     82         resign  black          15+15
# 18352  Pgee4CKk   True     50           mate  black          45+45
# 18353  MVxE7oz4  False     53           mate  white          15+15
# 18354  Pl7THFmZ  False     36         resign  black          15+15
# 18355  P0FNoKsw   True    100           draw   draw          45+45
# 18356  D6pNwmcM   True     59         resign  white           10+0
# 18357  cDSybWIj   True     43           mate  white           10+0
# 18358  iG5MuMz0   True     32           mate  black           10+0
# 18359  xAQi2hl2   True     36         resign  black          15+15
# 18360  NWgLdNx8   True     57         resign  white          45+45
# 18361  yM2DgyaO   True     87         resign  black          10+10
# 18362  B4IEyQyb   True     58           mate  black          10+10
# 18363  5Fx8GBTL   True     53         resign  white          10+10
# 18364  Z490CURF   True     11         resign  white          10+10
# 18365  PVqRI7Ma   True     37           mate  white          10+10
# 18366  e5jFywx3   True     70         resign  white          45+45
# 18367  tM5wivnc   True     36           mate  black          10+10
# 18368  X0DJ1fJu   True     73           mate  white          10+10
# 18369  dnexZDsv   True     25         resign  white          10+10
# 18370  7IENcPg3   True     43           mate  white           10+0
# 18371  uMzb0TPC   True     58           mate  black          10+10
# 18372  EopEqqAa   True     37         resign  white          10+10
# 18373  EfqH7VVH   True     24         resign  white          10+10
# 18374  WSJDhbPl   True     82           mate  black           10+0
# 18375  yrAas0Kj   True     35           mate  white           10+0
# 18376  b0v4tRyF   True    109         resign  white           10+0
# 18377  N8G2JHGG   True     78           mate  black           10+0
#
#                  White ID  White Rating            Black ID  Black Rating  \
# 0                    a-00          1322           skinnerua          1261
# 1                  ischia          1496                a-00          1500
# 2           daniamurashov          1439        adivanov2009          1454
# 3               nik221107          1523        adivanov2009          1469
# 4               trelynn17          1250       franklin14532          1002
# 5                 capa_jr          1520  daniel_likes_chess          1423
# 6      daniel_likes_chess          1413            soultego          2108
# 7               ehabfanri          1439  daniel_likes_chess          1392
# 8      daniel_likes_chess          1381             mirco25          1209
# 9      daniel_likes_chess          1381            anaissac          1272
# 10     daniel_likes_chess          1381           subham777          1867
# 11     daniel_likes_chess          1381       roman12342005          1936
# 12     daniel_likes_chess          1381              alkhan          1607
# 13      shivangithegenius          1094       sureka_akshat          1141
# 14          sureka_akshat          1141   shivangithegenius          1094
# 15      shivangithegenius          1094       sureka_akshat          1141
# 16          sureka_akshat          1141   shivangithegenius          1094
# 17      shivangithegenius          1094           slam_ment          1300
# 18                  g-ios          1500   shivangithegenius          1094
# 19      shivangithegenius          1094              lex_v1          1676
# 20      shivangithegenius          1094  themannichreaction          1068
# 21             storm28rus          1500   shivangithegenius          1094
# 22             robotsmoke          1307   shivangithegenius          1106
# 23      shivangithegenius          1113     ivangonzalez123          1423
# 24      shivangithegenius          1078       sureka_akshat          1219
# 25           gmcarlsen403          1825   shivangithegenius          1079
# 26                mannat1          1328   shivangithegenius          1038
# 27      shivangithegenius          1056      biyanivedant01          1156
# 28      shivangithegenius          1077       chinmaysharma          1148
# 29         biyanivedant01          1358   shivangithegenius          1036
# ...                   ...           ...                 ...           ...
# 18348        alexandre789          1842              lynnpv          1885
# 18349              lynnpv          1878          magnosouza          1720
# 18350              lynnpv          1890            gas_1948          1866
# 18351            gas_1948          1876              lynnpv          1879
# 18352            jamboger          1267       marshmallow55          1616
# 18353           fuoconero          1253            jamboger          1267
# 18354            jamboger          1267           fuoconero          1253
# 18355            jamboger          1258              nadgob          1620
# 18356          kaashish27          1427            jamboger          1265
# 18357            jamboger          1247               mhm98          1436
# 18358        egor_antonov          1156            jamboger          1238
# 18359            jamboger          1247               jcv29          1359
# 18360            oddskill          1550            jamboger          1250
# 18361            jamboger          1261                lyca          1461
# 18362            jamboger          1263        kevineclmans          1770
# 18363        kevineclmans          1759            jamboger          1265
# 18364            jamboger          1252            uwe_liem          1290
# 18365           shchuchin          1523            jamboger          1256
# 18366            jamboger          1246            seabacon          1201
# 18367       mateuslichess          1250            jamboger          1235
# 18368            jamboger          1222       mateuslichess          1262
# 18369       mateuslichess          1252            jamboger          1233
# 18370             jkubb29          1328            jamboger          1252
# 18371            samael88          1237            jamboger          1231
# 18372            jamboger          1219            samael88          1250
# 18373             belcolt          1691            jamboger          1220
# 18374            jamboger          1233  farrukhasomiddinov          1196
# 18375            jamboger          1219        schaaksmurf3          1286
# 18376        marcodisogno          1360            jamboger          1227
# 18377            jamboger          1235               ffbob          1339
#
#                                                    Moves Opening ECO  \
# 0      d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 1      e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
# 2      d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...         D02
# 3      e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...         C41
# 4                                       e4 c5 Nf3 Qa5 a3         B27
# 5      d4 d5 e4 dxe4 Nc3 Nf6 f3 exf3 Nxf3 Nc6 Bb5 a6 ...         D00
# 6                         e4 Nc6 d4 e5 d5 Nce7 c3 Ng6 b4         B00
# 7      e4 e5 Bc4 Nc6 Nf3 Nd4 d3 Nxf3+ Qxf3 Nf6 h3 Bc5...         C50
# 8      e4 d5 exd5 Qxd5 Nc3 Qe5+ Be2 Na6 d4 Qf5 Bxa6 b...         B01
# 9      e3 e6 d4 d6 Bd3 c6 Nf3 Be7 Nc3 Nf6 Bd2 Bd7 Qe2...         A00
# 10     e4 e6 d4 d5 e5 c5 c3 Nc6 Nf3 Qb6 Be3 Qxb2 Nbd2...         C02
# 11     e4 e6 Nf3 d5 exd5 exd5 Qe2+ Be7 Nc3 Nf6 d4 O-O...         C00
# 12     e4 e6 Qh5 g6 Qe5 Nf6 d4 d6 Qb5+ Bd7 Qxb7 Bc6 Q...         C00
# 13     e4 e5 Nf3 Nc6 Bc4 Nf6 Nc3 Bc5 O-O O-O d3 Ne8 B...         C50
# 14     e4 e5 Nf3 Nc6 Bc4 Nf6 Ng5 Qe7 O-O Nxe4 Nxe4 h6...         C57
# 15     e4 e5 Nf3 Nc6 Bc4 Nf6 Nc3 Bc5 O-O O-O Ne1 d6 d...         C50
# 16     e4 e5 Nf3 Nc6 Bc4 Nf6 Nc3 Bc5 O-O O-O Ne1 Ne8 ...         C50
# 17     e4 e5 Nf3 d6 Bc4 Be6 d3 Bxc4 dxc4 c5 O-O h6 Nc...         C41
# 18     d4 d5 h3 Nc6 Nf3 Nf6 Bg5 h6 Bxf6 exf6 e3 Bb4+ ...         D00
# 19     e4 e5 Nf3 Nc6 Bc4 h6 O-O Bc5 d3 Nf6 Nc3 Ng4 h3...         C55
# 20                                             d4 e6 Nc3         A40
# 21     e4 c5 Bc4 Nf6 Nc3 d6 Nf3 g6 Ng5 e6 d3 Bg7 O-O ...         B20
# 22     c4 Nc6 Nc3 e5 g3 Bc5 Bg2 Nge7 e3 b6 a3 Bb7 b4 ...         A25
# 23      e4 c5 d4 cxd4 Qxd4 Nc6 Qa4 e5 Be3 Nf6 Nf3 h6 Nc3         B21
# 24     d4 d5 Nc3 Nf6 Bf4 Bf5 Nf3 e6 e3 Be7 Bb5+ c6 Bd...         D01
# 25     e4 e5 Nf3 Nc6 d4 exd4 Bc4 Bc5 c3 dxc3 Bxf7+ Kx...         C45
# 26     d4 d5 Nc3 Nf6 Nf3 Nc6 e3 Bf5 h4 e6 g3 Bb4 a3 B...         D01
# 27     d4 d5 c4 c6 e3 dxc4 Bxc4 Nf6 Nc3 e6 e4 e5 d5 c...         D10
# 28     d4 d5 c4 Nf6 Nc3 Nc6 Nf3 e6 e3 Bd6 Bd3 Ne4 Bxe...         D06
# 29     e4 c5 d4 cxd4 Qxd4 Nc6 Qa4 Nf6 Nc3 g6 Nf3 Bg7 ...         B21
# ...                                                  ...         ...
# 18348  e4 c5 d4 cxd4 c3 dxc3 Bc4 cxb2 Bxb2 e6 Nf3 Bc5...         B21
# 18349  c4 d5 cxd5 Qxd5 Nc3 Qf5 Nf3 e5 e4 Qg4 Nxe5 Qe6...         A10
# 18350  c4 c6 Nf3 d5 c5 Nf6 d4 Bg4 Nc3 Nbd7 e3 e5 dxe5...         A11
# 18351  e4 c5 Nf3 g6 d4 cxd4 Nxd4 Bg7 Be3 Nf6 Bd3 O-O ...         A42
# 18352  c4 Nf6 Nc3 d5 c5 a5 d4 e6 Nf3 h6 Bf4 Nc6 e3 Nh...         A16
# 18353  e4 d6 d4 Nf6 Nc3 Nbd7 Qf3 e5 dxe5 Nxe5 Qd1 Bg4...         B07
# 18354  d4 e6 Bf4 Nf6 e3 d6 c3 e5 Bg3 exd4 cxd4 Ne4 Bh...         A40
# 18355  c4 e5 Nc3 Nf6 Nf3 Nc6 d4 exd4 Nxd4 Nxd4 Qxd4 c...         A28
# 18356  e4 d6 d4 Nf6 Nc3 Nc6 Nf3 e5 dxe5 dxe5 Qxd8+ Kx...         B07
# 18357  c4 e5 Nc3 Bc5 e3 Nc6 a3 Nf6 b4 Bd6 Nf3 a6 c5 B...         A21
# 18358  e4 d6 Qh5 Nf6 Qh6 gxh6 Bb5+ Nc6 Ba4 e5 Nf3 Bd7...         B07
# 18359  c4 e5 Nc3 Bb4 Nd5 a5 Nf3 Nc6 a3 Bc5 d3 Nf6 Bd2...         A21
# 18360  e4 e5 Nf3 Nc6 Bc4 Bc5 b4 Bxb4 c3 Ba5 Qb3 Qf6 O...         C52
# 18361  c4 Nf6 d4 e6 Nc3 Bb4 Bd2 c5 Be3 b6 Nf3 Bb7 g3 ...         E20
# 18362  d4 d5 Bf4 Bf5 e3 Nf6 c3 e6 Nf3 Nh5 Bg5 f6 Bh4 ...         D00
# 18363  e4 d6 d4 Nf6 Nc3 Nbd7 f4 e5 Nf3 Be7 dxe5 dxe5 ...         B07
# 18364          c4 Nf6 Nc3 d5 cxd5 Nxd5 e4 Nf4 d4 c6 Bxf4         A16
# 18365  e4 e6 d4 d5 e5 Nc6 Nf3 f6 Bb5 Bd7 O-O Nge7 exf...         C02
# 18366  e4 c5 c3 g6 d4 d6 Nf3 Nf6 e5 dxe5 Nxe5 Bg7 Bc4...         B22
# 18367  e4 d6 d4 Nf6 e5 dxe5 Be2 exd4 Nf3 Nc6 O-O e5 B...         B07
# 18368  c4 d5 e3 dxc4 Bxc4 Nc6 a3 Ne5 d4 Nxc4 Nc3 e5 N...         A10
# 18369  e4 e6 d4 d5 exd5 Qxd5 Nc3 Bb4 a3 Bxc3+ bxc3 Ne...         C01
# 18370  e4 e6 Nf3 d5 Nc3 Bb4 exd5 exd5 d4 Bg4 a3 Bxc3+...         C00
# 18371  e4 e6 Nf3 d5 Bb5+ Bd7 c4 c6 Ba4 Qa5 b3 b5 cxb5...         C00
# 18372  c4 e6 d4 b6 Nc3 Bb7 Nf3 g6 h4 Bg7 Bg5 f6 Bf4 d...         A40
# 18373  d4 f5 e3 e6 Nf3 Nf6 Nc3 b6 Be2 Bb7 O-O Be7 Ne5...         A80
# 18374  d4 d6 Bf4 e5 Bg3 Nf6 e3 exd4 exd4 d5 c3 Bd6 Bd...         A41
# 18375  d4 d5 Bf4 Nc6 e3 Nf6 c3 e6 Nf3 Be7 Bd3 O-O Nbd...         D00
# 18376  e4 d6 d4 Nf6 e5 dxe5 dxe5 Qxd1+ Kxd1 Nd5 c4 Nb...         B07
# 18377  d4 d5 Bf4 Na6 e3 e6 c3 Nf6 Nf3 Bd7 Nbd2 b5 Bd3...         D00
#
#                                             Opening Name  Opening Ply  \
# 0                 Nimzowitsch Defense: Kennedy Variation            4
# 1                  King's Pawn Game: Leonardis Variation            3
# 2                 Queen's Pawn Game: Zukertort Variation            3
# 3                                       Philidor Defense            5
# 4                   Sicilian Defense: Mongoose Variation            4
# 5             Blackmar-Diemer Gambit: Pietrowsky Defense           10
# 6      Nimzowitsch Defense: Kennedy Variation |  Link...            5
# 7                  Italian Game: Schilling-Kostic Gambit            6
# 8          Scandinavian Defense: Mieses-Kotroc Variation            4
# 9                                   Van't Kruijs Opening            1
# 10     French Defense: Advance Variation |  Paulsen A...            9
# 11                      French Defense: Knight Variation            3
# 12                                     French Defense #2            2
# 13                  Four Knights Game: Italian Variation            8
# 14     Italian Game: Two Knights Defense |  Knight At...            7
# 15                  Four Knights Game: Italian Variation            8
# 16                  Four Knights Game: Italian Variation            8
# 17                                   Philidor Defense #3            5
# 18                                     Queen's Pawn Game            2
# 19                Italian Game: Anti-Fried Liver Defense            6
# 20                                       Horwitz Defense            2
# 21                      Sicilian Defense: Bowdler Attack            3
# 22     English Opening: King's English Variation |  R...            4
# 23               Sicilian Defense: Smith-Morra Gambit #2            3
# 24                 Queen's Pawn Game: Chigorin Variation            4
# 25                              Scotch Game: Haxo Gambit            8
# 26                 Queen's Pawn Game: Chigorin Variation            4
# 27                                          Slav Defense            4
# 28              Queen's Gambit Refused: Marshall Defense            4
# 29               Sicilian Defense: Smith-Morra Gambit #2            3
# ...                                                  ...          ...
# 18348               Sicilian Defense: Smith-Morra Gambit            5
# 18349        English Opening: Anglo-Scandinavian Defense            2
# 18350        English Opening: Caro-Kann Defensive System            2
# 18351      Sicilian Defense: Hyperaccelerated Fianchetto            5
# 18352           English Opening: Anglo-Gruenfeld Defense            4
# 18353                                    Pirc Defense #2            5
# 18354                                    Horwitz Defense            2
# 18355  English Opening: King's English Variation |  F...            6
# 18356                                    Pirc Defense #2            5
# 18357  English Opening: King's English Variation |  R...            3
# 18358                                    Pirc Defense #4            2
# 18359  English Opening: King's English Variation |  K...            4
# 18360            Italian Game: Evans Gambit |  Main Line           10
# 18361                               Nimzo-Indian Defense            6
# 18362                    Queen's Pawn Game: Mason Attack            3
# 18363         Lion Defense: Anti-Philidor |  Lion's Cave            8
# 18364           English Opening: Anglo-Gruenfeld Defense            4
# 18365               French Defense: Advance Variation #3            5
# 18366                 Sicilian Defense: Alapin Variation            3
# 18367                                       Pirc Defense            4
# 18368        English Opening: Anglo-Scandinavian Defense            2
# 18369                 French Defense: Exchange Variation            5
# 18370              French Defense: Two Knights Variation            5
# 18371                   French Defense: Knight Variation            3
# 18372                                    English Defense            4
# 18373                                      Dutch Defense            2
# 18374                                       Queen's Pawn            2
# 18375                    Queen's Pawn Game: Mason Attack            3
# 18376                                       Pirc Defense            4
# 18377                    Queen's Pawn Game: Mason Attack            3
#
#        Skill Disparity Favored  Upset Disparity Group
# 0                   61   white   True           0-100
# 1                    4   black   True           0-100
# 2                   15   black   True           0-100
# 3                   54   white  False           0-100
# 4                  248   white  False         201-300
# 5                   97   white  False           0-100
# 6                  695   black  False         601-700
# 7                   47   white   True           0-100
# 8                  172   white  False         101-200
# 9                  109   white  False         101-200
# 10                 486   black  False         401-500
# 11                 555   black  False         501-600
# 12                 226   black  False         201-300
# 13                  47   black   True           0-100
# 14                  47   white   True           0-100
# 15                  47   black  False           0-100
# 16                  47   white   True           0-100
# 17                 206   black  False         201-300
# 18                 406   white  False         401-500
# 19                 582   black  False         501-600
# 20                  26   white  False           0-100
# 21                 406   white  False         401-500
# 22                 201   white  False         201-300
# 23                 310   black  False         301-400
# 24                 141   black   True         101-200
# 25                 746   white  False         701-800
# 26                 290   white   True         201-300
# 27                 100   black  False           0-100
# 28                  71   black  False           0-100
# 29                 322   white   True         301-400
# ...                ...     ...    ...             ...
# 18348               43   black   True           0-100
# 18349              158   white  False         101-200
# 18350               24   white   True           0-100
# 18351                3   black  False           0-100
# 18352              349   black  False         301-400
# 18353               14   black   True           0-100
# 18354               14   white   True           0-100
# 18355              362   black  False         301-400
# 18356              162   white  False         101-200
# 18357              189   black   True         101-200
# 18358               82   black  False           0-100
# 18359              112   black  False         101-200
# 18360              300   white  False         201-300
# 18361              200   black  False         101-200
# 18362              507   black  False         501-600
# 18363              494   white  False         401-500
# 18364               38   black   True           0-100
# 18365              267   white  False         201-300
# 18366               45   white  False           0-100
# 18367               15   white   True           0-100
# 18368               40   black   True           0-100
# 18369               19   white  False           0-100
# 18370               76   white  False           0-100
# 18371                6   white   True           0-100
# 18372               31   black   True           0-100
# 18373              471   white  False         401-500
# 18374               37   white   True           0-100
# 18375               67   black   True           0-100
# 18376              133   white  False         101-200
# 18377              104   black  False         101-200
#
# [18378 rows x 18 columns]

# %%
games_upset = games.loc[games["Upset"] == "True"]
upset = games_upset["Upset"].count()
games_expected = games.loc[games["Upset"] == "False"]
expected = games_expected["Upset"].count()

total_games = upset + expected
upset_percent = round(100 * upset/total_games, 2)
expected_percent = round(100 * expected/total_games, 2)


print(f"Total games: {total_games}")
print(f"Number of upset victories: {upset}, ({upset_percent}%)")
print(f"Number of expected victories: {expected}, ({expected_percent}%)")
# Out:
# Total games: 18378
# Number of upset victories: 6024, (32.78%)
# Number of expected victories: 12354, (67.22%)

# %%
# Disparity groups of each match
disparity_matches = games.groupby(games["Disparity Group"]).count()["Game ID"]
disparity_matches
# Out:
# Disparity Group
# 0-100       8164
# 101-200     4165
# 201-300     2478
# 301-400     1405
# 401-500      821
# 501-600      525
# 601-700      267
# 701-800      161
# 801-900       89
# 901-1000      67
# 1000+         50
# Name: Game ID, dtype: int64

# %%
# Upsets by disparity group
group_1 = games.loc[games["Disparity Group"] == "0-100"]
group_2 = games.loc[games["Disparity Group"] == "101-200"]
group_3 = games.loc[games["Disparity Group"] == "201-300"]
group_4 = games.loc[games["Disparity Group"] == "301-400"]
group_5 = games.loc[games["Disparity Group"] == "401-500"]
group_6 = games.loc[games["Disparity Group"] == "501-600"]
group_7 = games.loc[games["Disparity Group"] == "601-700"]
group_8 = games.loc[games["Disparity Group"] == "701-800"]
group_9 = games.loc[games["Disparity Group"] == "801-900"]
group_10 = games.loc[games["Disparity Group"] == "901-1000"]
group_11 = games.loc[games["Disparity Group"] == "1000+"]

group_1.head()
# Out:
#     Game ID  Rated  Turns Victory Status Winner Increment Code       White ID  \
# 0  l1NXvwaE   True     16         resign  black           5+10           a-00
# 1  mIICvQHh   True     61           mate  white           5+10         ischia
# 2  kWKvrqYL   True     61           mate  white           20+0  daniamurashov
# 3  9tXo1AUZ   True     95           mate  white           30+3      nik221107
# 5  qwU9rasv   True     33         resign  white           10+0        capa_jr
#
#    White Rating            Black ID  Black Rating  \
# 0          1322           skinnerua          1261
# 1          1496                a-00          1500
# 2          1439        adivanov2009          1454
# 3          1523        adivanov2009          1469
# 5          1520  daniel_likes_chess          1423
#
#                                                Moves Opening ECO  \
# 0  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 1  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
# 2  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...         D02
# 3  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...         C41
# 5  d4 d5 e4 dxe4 Nc3 Nf6 f3 exf3 Nxf3 Nc6 Bb5 a6 ...         D00
#
#                                  Opening Name  Opening Ply  Skill Disparity  \
# 0      Nimzowitsch Defense: Kennedy Variation            4               61
# 1       King's Pawn Game: Leonardis Variation            3                4
# 2      Queen's Pawn Game: Zukertort Variation            3               15
# 3                            Philidor Defense            5               54
# 5  Blackmar-Diemer Gambit: Pietrowsky Defense           10               97
#
#   Favored  Upset Disparity Group
# 0   white   True           0-100
# 1   black   True           0-100
# 2   black   True           0-100
# 3   white  False           0-100
# 5   white  False           0-100

# %%
# Upsets in 0-100 group
upset_1 = group_1.loc[group_1["Upset"] == "True"].count()["Upset"]
expect_1 = group_1.loc[group_1["Upset"] != "True"].count()["Upset"]
total_1 = upset_1 + expect_1
print(f"Upsets: {upset_1}")
print(f"Expected: {expect_1}")
print(f"Total Matches: {total_1}")
# Out:
# Upsets: 3514
# Expected: 4650
# Total Matches: 8164

# %%
# Upsets in 101-200 group
upset_2 = group_2.loc[group_2["Upset"] == "True"].count()["Upset"]
upset_2_p = round(100 * upset_2/disparity_matches[1], 2)
print(f"Upsets (101-200): {upset_2} ({upset_2_p}%)")

# Upsets in 201-300 group
upset_3 = group_3.loc[group_3["Upset"] == "True"].count()["Upset"]
upset_3_p = round(100 * upset_3/disparity_matches[2], 2)
print(f"Upsets (201-300): {upset_3} ({upset_3_p}%)")

# Upsets in 301-400 group
upset_4 = group_4.loc[group_4["Upset"] == "True"].count()["Upset"]
upset_4_p = round(100 * upset_4/disparity_matches[3], 2)
print(f"Upsets (301-400): {upset_4} ({upset_4_p}%)")

# Upsets in 401-500 group
upset_5 = group_5.loc[group_5["Upset"] == "True"].count()["Upset"]
upset_5_p = round(100 * upset_5/disparity_matches[4], 2)
print(f"Upsets (401-500): {upset_5} ({upset_5_p}%)")

# Upsets in 501-600 group
upset_6 = group_6.loc[group_6["Upset"] == "True"].count()["Upset"]
upset_6_p = round(100 * upset_6/disparity_matches[5], 2)
print(f"Upsets (501-600): {upset_6} ({upset_6_p}%)")

# Upsets in 601-700 group
upset_7 = group_7.loc[group_7["Upset"] == "True"].count()["Upset"]
upset_7_p = round(100 * upset_7/disparity_matches[6], 2)
print(f"Upsets (601-700): {upset_7} ({upset_7_p}%)")

# Upsets in 701-800 group
upset_8 = group_8.loc[group_8["Upset"] == "True"].count()["Upset"]
upset_8_p = round(100 * upset_8/disparity_matches[7], 2)
print(f"Upsets (701-800): {upset_8} ({upset_8_p}%)")

# Upsets in 801-900 group
upset_9 = group_9.loc[group_9["Upset"] == "True"].count()["Upset"]
upset_9_p = round(100 * upset_9/disparity_matches[8], 2)
print(f"Upsets (801-900): {upset_9} ({upset_9_p}%)")

# Upsets in 901-1000 group 
upset_10 = group_10.loc[group_10["Upset"] == "True"].count()["Upset"]
upset_10_p = round(100 * upset_10/disparity_matches[9], 2)
print(f"Upsets (901-1000): {upset_10} ({upset_10_p}%)")

# Upsets in 1000+ group
upset_11 = group_11.loc[group_11["Upset"] == "True"].count()["Upset"]
upset_11_p = round(100 * upset_11/disparity_matches[10], 2)
print(f"Upsets (1000+): {upset_11} ({upset_11_p}%)")
# Out:
# Upsets (101-200): 1348 (32.36%)
# Upsets (201-300): 572 (23.08%)
# Upsets (301-400): 259 (18.43%)
# Upsets (401-500): 117 (14.25%)
# Upsets (501-600): 65 (12.38%)
# Upsets (601-700): 37 (13.86%)
# Upsets (701-800): 15 (9.32%)
# Upsets (801-900): 4 (4.49%)
# Upsets (901-1000): 2 (2.99%)
# Upsets (1000+): 2 (4.0%)
